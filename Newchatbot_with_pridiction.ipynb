# %%
from sentence_transformers import SentenceTransformer, InputExample, losses, util
import pandas as pd
import torch
from torch.utils.data import DataLoader
import os

# %%
# Step 1: Load FAQ and Next Question data from a single Excel file
faq_df = pd.read_excel("/WITDS_FAQ_Paraphrased.xlsx")  # Columns: Question, Answer, Next_Question
faq_df = faq_df.dropna(subset=["Question", "Answer"]).fillna("")
faq_df["Question"] = faq_df["Question"].astype(str)
faq_df["Answer"] = faq_df["Answer"].astype(str)
faq_df["Next_Question"] = faq_df["Next Question"].astype(str)

faq_questions = faq_df["Question"].tolist()
faq_answers = faq_df["Answer"].tolist()
next_question_map = dict(zip(faq_df["Question"], faq_df["Next Question"]))

# %%
# Step 2: Prepare training pairs for fine-tuning (same question used twice)
train_examples = [InputExample(texts=[q, q]) for q in faq_questions]
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)

# %%
# Step 3: Load base model and fine-tune it
model = SentenceTransformer("all-MiniLM-L6-v2")
train_loss = losses.MultipleNegativesRankingLoss(model)
model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=5,
    warmup_steps=10,
    show_progress_bar=True
)
# Out:
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: bibhavkumar05 (bibhavkumar05-upes) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250714_082113-rq60gzac</code>
# Syncing run <strong><a href='https://wandb.ai/bibhavkumar05-upes/sentence-transformers/runs/rq60gzac' target="_blank">checkpoints/model</a></strong> to <a href='https://wandb.ai/bibhavkumar05-upes/sentence-transformers' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/bibhavkumar05-upes/sentence-transformers' target="_blank">https://wandb.ai/bibhavkumar05-upes/sentence-transformers</a>
#  View run at <a href='https://wandb.ai/bibhavkumar05-upes/sentence-transformers/runs/rq60gzac' target="_blank">https://wandb.ai/bibhavkumar05-upes/sentence-transformers/runs/rq60gzac</a>
#     <div>
#
#       <progress value='680' max='680' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [680/680 00:31, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.010900</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Step 4: Save and reload fine-tuned model
fine_tuned_path = "finetuned_chatbot_model"
os.makedirs(fine_tuned_path, exist_ok=True)
model.save(fine_tuned_path)
model = SentenceTransformer(fine_tuned_path)

# %%
import shutil

# Compress the fine-tuned model directory into a zip file
model_folder = "finetuned_chatbot_model"
shutil.make_archive(model_folder, 'zip', model_folder)
print(f"✅ Model zipped as {model_folder}.zip")
# Out:
# ✅ Model zipped as finetuned_chatbot_model.zip

# %%
from google.colab import files
files.download("finetuned_chatbot_model.zip")

# %%
# Step 5: Encode FAQ questions
faq_embeddings = model.encode(faq_questions, convert_to_tensor=True)

# %%
# For duplicate detection
global_previous_questions = []

def is_duplicate(query, threshold=0.8):
    global global_previous_questions
    query_vec = model.encode(query, convert_to_tensor=True)
    for pq in global_previous_questions:
        pq_vec = model.encode(pq, convert_to_tensor=True)
        sim = util.cos_sim(query_vec, pq_vec).item()
        if sim > threshold:
            return True
    global_previous_questions.append(query)

# %%
def get_answer(query):
    query_vec = model.encode(query, convert_to_tensor=True)
    sims = util.cos_sim(query_vec, faq_embeddings)
    idx = torch.argmax(sims)
    return faq_answers[idx], faq_questions[idx]

# %%
def get_next_question(matched_question):
    next_q = next_question_map.get(matched_question, "")
    return next_q if next_q.strip() else None

# %%
def chatbot(query):
    if is_duplicate(query):
        return "You've already asked this or a similar question."
    answer, matched_question = get_answer(query)
    next_q = get_next_question(matched_question)
    if next_q:
        return f"{answer}\nWould you like to know: {next_q}"
    return answer

# %%
if __name__ == "__main__":
    print("Chatbot is ready. Type your question or type 'exit' to quit.")
    while True:
        user_input = input("You: ")
        if user_input.lower() in ["exit", "quit"]:
            print("Bot: Goodbye!")
            break
        response = chatbot(user_input)
        print("Bot:", response)
# Out:
# Chatbot is ready. Type your question or type 'exit' to quit.
# You: What is WITDS?
# Bot: WITDS is a Dehradun-based IT services company offering end-to-end digital solutions.
# Would you like to know: What benefits do long-term partnerships bring to clients working with WITDS?
# You: yes
# Bot: WITDS is a Dehradun-based IT services company offering end-to-end digital solutions.
# Would you like to know: What benefits do long-term partnerships bring to clients working with WITDS?
# You: Does WITDS offer mobile app development?
# Bot: Yes, WITDS provides full-cycle mobile app development services for both Android and iOS platforms.
# Would you like to know: What makes WITDS beneficial for enterprises?
# You: Does WITDS offer mobile app development?
# Bot: You've already asked this or a similar question.
# You: What is WITDS?
# Bot: You've already asked this or a similar question.
# You: How does WITDS approach a new project?
# Bot: WITDS begins with understanding the client’s needs, followed by strategy design, technology selection, iterative development, and deployment with ongoing support.
# Would you like to know: How can businesses reach support quickly?
# You: Does WITDS offer custom software development?
# Bot: Yes, WITDS specializes in building custom software tailored to your business requirements, from enterprise-level platforms to niche digital tools.
# Would you like to know: What is the process WITDS follows for custom software development?
# You: Does WITDS offer custom software development?
# Bot: You've already asked this or a similar question.
# You: What is WITDS known for in terms of service delivery?
# Bot: WITDS is known for its client-focused approach, ensuring tailored solutions that align closely with business objectives and industry needs.
# Would you like to know: How experienced is the WITDS team—what are their core areas of expertise?
# You: How experienced is the WITDS team—what are their core areas of expertise?
# Bot: WITDS has over a decade of experience, with expertise in app development, cloud solutions, UI/UX, eCommerce, AI/ML, and product re-engineering.
# You: Does WITDS provide digital marketing services?
# Bot: Yes, WITDS offers strategic digital marketing services to help businesses grow their online presence and reach their target audience effectively.
# Would you like to know: What specific digital marketing services does WITDS offer?
# You: What specific digital marketing services does WITDS offer?
# Bot: Services include SEO, SEM, content marketing, social media management, email marketing, and analytics to boost digital visibility and engagement.
# You: What is WITDS’s approach to UI/UX design?
# Bot: WITDS combines design thinking and user research to craft intuitive, engaging, and accessible user experiences across web and mobile platforms.
# Would you like to know: How does WITDS conduct user research and testing during the UI/UX design phase?
# You: How does WITDS conduct user research and testing during the UI/UX design phase?
# Bot: Through user interviews, surveys, usability testing, and A/B testing.
# You: How does WITDS ensure quality during each development stage?
# Bot: WITDS implements automated and manual testing, code reviews, QA sprints, and adherence to best practices at every development milestone.
# You: Full form of WITDS?
# Bot: WITDS stands for Web Innovation Technology & Digital Solutions.
# You: Why can I choose WITDS?
# Bot: WITDS combines cloud expertise with business understanding to deliver scalable, secure, and cost-effective cloud solutions tailored to your specific needs.
# Would you like to know: Can WITDS design a custom cloud architecture based on my business goals?
# You: Can WITDS design a custom cloud architecture based on my business goals?
# Bot: Features include product catalogs, cart management, secure checkout, order tracking, and analytics dashboards.
